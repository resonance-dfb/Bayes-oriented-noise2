# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import numpy as np
import math
import optuna
# 加载和预处理数据
transform = transforms.Compose([transforms.ToTensor()])
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=transform)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False)

# %%
class CustomReLU(nn.Module):
    def __init__(self, sigma):
        super().__init__()
        self.sigma = nn.Parameter(torch.tensor(sigma))  # 1个可学习参数 sigma

    def forward(self, input):
        return torch.max(input, self.sigma * input)

class Net(nn.Module):
    def __init__(self, sigma):
        super(Net, self).__init__()
        self.flatten = nn.Flatten()  # 28*28二维图像展平成一维向量，size=784
        self.fc1 = nn.Linear(28 * 28, 30)  # 784维映射到128维
        self.custom_relu = CustomReLU(sigma)  # 自定义ReLU层
        self.dropout = nn.Dropout(0.5)  # 舍去50%的神经元
        self.fc2 = nn.Linear(30, 10)  # 128维映射到10维

    def forward(self, x):
        x = self.flatten(x)
        x = self.fc1(x)
        x = self.custom_relu(x)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
def objective(trial):
    sigma = trial.suggest_float("sigma", 0.1, 7.0)  # 使用 Optuna 建议 sigma 值
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = Net(sigma).to(device)
    criterion = nn.CrossEntropyLoss()  # 交叉熵损失函数
    optimizer = optim.Adam(model.parameters(), lr=0.01)

    num_epochs = 10
    for epoch in range(num_epochs):
        model.train()  # 将模型设置为训练模式，以便在前向传播时启用 Dropout 和 BatchNorm
        running_loss = 0.0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

    # 在测试集上验证模型
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():  # 在验证过程中禁用梯度计算，以提高计算速度和节省内存。
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = 100 * correct / total

    return accuracy

# %%
# 运行优化
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=20)

# 获取最佳 sigma 值
best_sigma = study.best_params["sigma"]
print("Best sigma:", best_sigma)
# Out:
# [I 2024-07-21 17:08:25,015] A new study created in memory with name: no-name-4a8a87bc-08d5-41c0-92c5-74af07def818
# [I 2024-07-21 17:09:47,922] Trial 0 finished with value: 93.95 and parameters: {'sigma': 2.795975126610662}. Best is trial 0 with value: 93.95.
# [I 2024-07-21 17:11:11,577] Trial 1 finished with value: 93.95 and parameters: {'sigma': 3.057043900767174}. Best is trial 0 with value: 93.95.
# [I 2024-07-21 17:12:41,000] Trial 2 finished with value: 93.93 and parameters: {'sigma': 5.640697357002357}. Best is trial 0 with value: 93.95.
# [I 2024-07-21 17:14:08,564] Trial 3 finished with value: 93.78 and parameters: {'sigma': 3.3601340757352074}. Best is trial 0 with value: 93.95.
# [I 2024-07-21 17:15:35,984] Trial 4 finished with value: 93.54 and parameters: {'sigma': 5.000104940219762}. Best is trial 0 with value: 93.95.
# [I 2024-07-21 17:17:00,673] Trial 5 finished with value: 93.46 and parameters: {'sigma': 6.5925269667022555}. Best is trial 0 with value: 93.95.
# [I 2024-07-21 17:18:28,142] Trial 6 finished with value: 93.37 and parameters: {'sigma': 3.1909652478476596}. Best is trial 0 with value: 93.95.
# [I 2024-07-21 17:19:54,670] Trial 7 finished with value: 93.74 and parameters: {'sigma': 5.395941324061532}. Best is trial 0 with value: 93.95.
# [I 2024-07-21 17:21:25,271] Trial 8 finished with value: 93.52 and parameters: {'sigma': 2.327858553360311}. Best is trial 0 with value: 93.95.
# [I 2024-07-21 17:22:46,748] Trial 9 finished with value: 94.05 and parameters: {'sigma': 3.3431943773904127}. Best is trial 9 with value: 94.05.
# [I 2024-07-21 17:24:20,718] Trial 10 finished with value: 93.73 and parameters: {'sigma': 0.4029081777404353}. Best is trial 9 with value: 94.05.
# [I 2024-07-21 17:25:44,522] Trial 11 finished with value: 93.68 and parameters: {'sigma': 1.45046990019848}. Best is trial 9 with value: 94.05.
# [I 2024-07-21 17:27:10,664] Trial 12 finished with value: 93.93 and parameters: {'sigma': 4.272589106895362}. Best is trial 9 with value: 94.05.
# [I 2024-07-21 17:28:37,700] Trial 13 finished with value: 93.73 and parameters: {'sigma': 2.0259951410271366}. Best is trial 9 with value: 94.05.
# [I 2024-07-21 17:30:05,962] Trial 14 finished with value: 93.57 and parameters: {'sigma': 4.25942249329448}. Best is trial 9 with value: 94.05.
# [I 2024-07-21 17:31:34,230] Trial 15 finished with value: 93.52 and parameters: {'sigma': 1.3041580349959558}. Best is trial 9 with value: 94.05.
# [I 2024-07-21 17:33:03,064] Trial 16 finished with value: 93.75 and parameters: {'sigma': 4.262012759978915}. Best is trial 9 with value: 94.05.
# [I 2024-07-21 17:34:31,861] Trial 17 finished with value: 94.24 and parameters: {'sigma': 2.4545961693131755}. Best is trial 17 with value: 94.24.
# [I 2024-07-21 17:36:01,059] Trial 18 finished with value: 94.01 and parameters: {'sigma': 0.6040393058825666}. Best is trial 17 with value: 94.24.
# [I 2024-07-21 17:37:30,052] Trial 19 finished with value: 94.02 and parameters: {'sigma': 2.224820402320082}. Best is trial 17 with value: 94.24.
# Best sigma: 2.4545961693131755

# %%
# 实例化模型、定义损失函数和优化器
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net(best_sigma).to(device)
criterion = nn.CrossEntropyLoss()  # 交叉熵损失函数
optimizer = optim.Adam(model.parameters(), lr=0.01)

num_epochs = 50


for epoch in range(num_epochs):
    model.train()  # 将模型设置为训练模式，以便在前向传播时启用 Dropout 和 BatchNorm
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()
        running_loss += loss.item()

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(train_loader):.4f}')

    # 在测试集上验证模型
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():  # 在验证过程中禁用梯度计算，以提高计算速度和节省内存。
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print(f'Accuracy of the network on the 10000 test images: {100 * correct / total:.2f}%')

print('Finished Training')
# Out:
# Epoch [1/50], Loss: 0.5626
# Accuracy of the network on the 10000 test images: 90.58%
# Epoch [2/50], Loss: 0.4628
# Accuracy of the network on the 10000 test images: 92.00%
# Epoch [3/50], Loss: 0.4398
# Accuracy of the network on the 10000 test images: 92.77%
# Epoch [4/50], Loss: 0.4335
# Accuracy of the network on the 10000 test images: 92.70%
# Epoch [5/50], Loss: 0.4270
# Accuracy of the network on the 10000 test images: 93.03%
# Epoch [6/50], Loss: 0.4204
# Accuracy of the network on the 10000 test images: 93.19%
# Epoch [7/50], Loss: 0.4148
# Accuracy of the network on the 10000 test images: 92.83%
# Epoch [8/50], Loss: 0.4149
# Accuracy of the network on the 10000 test images: 93.43%
# Epoch [9/50], Loss: 0.4094
# Accuracy of the network on the 10000 test images: 93.74%
# Epoch [10/50], Loss: 0.4045
# Accuracy of the network on the 10000 test images: 94.05%
# Epoch [11/50], Loss: 0.3984
# Accuracy of the network on the 10000 test images: 93.42%
# Epoch [12/50], Loss: 0.4002
# Accuracy of the network on the 10000 test images: 94.02%
# Epoch [13/50], Loss: 0.3997
# Accuracy of the network on the 10000 test images: 94.04%
# Epoch [14/50], Loss: 0.3876
# Accuracy of the network on the 10000 test images: 93.70%
# Epoch [15/50], Loss: 0.3917
# Accuracy of the network on the 10000 test images: 94.12%
# Epoch [16/50], Loss: 0.3886
# Accuracy of the network on the 10000 test images: 94.01%
# Epoch [17/50], Loss: 0.3850
# Accuracy of the network on the 10000 test images: 93.88%
# Epoch [18/50], Loss: 0.3832
# Accuracy of the network on the 10000 test images: 94.45%
# Epoch [19/50], Loss: 0.3832
# Accuracy of the network on the 10000 test images: 93.97%
# Epoch [20/50], Loss: 0.3791
# Accuracy of the network on the 10000 test images: 94.26%
# Epoch [21/50], Loss: 0.3830
# Accuracy of the network on the 10000 test images: 94.16%
# Epoch [22/50], Loss: 0.3823
# Accuracy of the network on the 10000 test images: 94.15%
# Epoch [23/50], Loss: 0.3727
# Accuracy of the network on the 10000 test images: 94.45%
# Epoch [24/50], Loss: 0.3828
# Accuracy of the network on the 10000 test images: 94.19%
# Epoch [25/50], Loss: 0.3757
# Accuracy of the network on the 10000 test images: 94.31%
# Epoch [26/50], Loss: 0.3804
# Accuracy of the network on the 10000 test images: 94.50%
# Epoch [27/50], Loss: 0.3743
# Accuracy of the network on the 10000 test images: 94.35%
# Epoch [28/50], Loss: 0.3754
# Accuracy of the network on the 10000 test images: 94.36%
# Epoch [29/50], Loss: 0.3694
# Accuracy of the network on the 10000 test images: 94.70%
# Epoch [30/50], Loss: 0.3691
# Accuracy of the network on the 10000 test images: 94.01%
# Epoch [31/50], Loss: 0.3753
# Accuracy of the network on the 10000 test images: 94.22%
# Epoch [32/50], Loss: 0.3660
# Accuracy of the network on the 10000 test images: 94.62%
# Epoch [33/50], Loss: 0.3673
# Accuracy of the network on the 10000 test images: 94.38%
# Epoch [34/50], Loss: 0.3671
# Accuracy of the network on the 10000 test images: 94.38%
# Epoch [35/50], Loss: 0.3737
# Accuracy of the network on the 10000 test images: 94.40%
# Epoch [36/50], Loss: 0.3699
# Accuracy of the network on the 10000 test images: 94.57%
# Epoch [37/50], Loss: 0.3706
# Accuracy of the network on the 10000 test images: 94.20%
# Epoch [38/50], Loss: 0.3641
# Accuracy of the network on the 10000 test images: 94.41%
# Epoch [39/50], Loss: 0.3681
# Accuracy of the network on the 10000 test images: 94.37%
# Epoch [40/50], Loss: 0.3660
# Accuracy of the network on the 10000 test images: 93.66%
# Epoch [41/50], Loss: 0.3699
# Accuracy of the network on the 10000 test images: 94.37%
# Epoch [42/50], Loss: 0.3626
# Accuracy of the network on the 10000 test images: 94.33%
# Epoch [43/50], Loss: 0.3640
# Accuracy of the network on the 10000 test images: 94.62%
# Epoch [44/50], Loss: 0.3603
# Accuracy of the network on the 10000 test images: 94.50%
# Epoch [45/50], Loss: 0.3632
# Accuracy of the network on the 10000 test images: 94.36%
# Epoch [46/50], Loss: 0.3604
# Accuracy of the network on the 10000 test images: 94.58%
# Epoch [47/50], Loss: 0.3650
# Accuracy of the network on the 10000 test images: 94.64%
# Epoch [48/50], Loss: 0.3660
# Accuracy of the network on the 10000 test images: 94.41%
# Epoch [49/50], Loss: 0.3645
# Accuracy of the network on the 10000 test images: 94.24%
# Epoch [50/50], Loss: 0.3628
# Accuracy of the network on the 10000 test images: 94.33%
# Finished Training
